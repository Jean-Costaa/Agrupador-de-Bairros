# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LinearRing, Polygon
from folium.plugins import FastMarkerCluster
import folium
import pandas as pd
import openpyxl
import os


def carregar_mapa(estado_selecionado):
    if estado_selecionado == "Rio Grande do Norte":

        filename = "G:\Meu Drive\Projetos\Poligonos_Shopee\data\RN_bairros_municipios.json"

        mapa = gpd.read_file(filename, driver='GeoJSON')

        return mapa
    
    
mapa = carregar_mapa('Rio Grande do Norte')    
mapa.plot(facecolor='none', edgecolor='black')
# Out:
# g:\Meu Drive\Projetos\Poligonos_Shopee\.venv\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: driver GeoJSON does not support open option DRIVER
#   return ogr_read(
# <Axes: >
